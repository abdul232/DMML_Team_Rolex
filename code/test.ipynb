# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import collections  as mc
# %load_ext autoreload
# %autoreload 2
import pandas as pd 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
sns.set_style("white")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv('https://raw.githubusercontent.com/ahmadajal/DM_ML_course_public/master/2%263.%20Data%26EDA/data/cars.csv')
# view the first 5 rows 
data
# Out:
#     YEAR        Make                            Model  ... RATING  (km) TIME (h)
# 0   2012  MITSUBISHI                           i-MiEV  ...    NaN   100        7
# 1   2012      NISSAN                             LEAF  ...    NaN   117        7
# 2   2013        FORD                   FOCUS ELECTRIC  ...    NaN   122        4
# 3   2013  MITSUBISHI                           i-MiEV  ...    NaN   100        7
# 4   2013      NISSAN                             LEAF  ...    NaN   117        7
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  ...    NaN   109        8
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE  ...    NaN   109        8
# 7   2013       TESLA         MODEL S (40 kWh battery)  ...    NaN   224        6
# 8   2013       TESLA         MODEL S (60 kWh battery)  ...    NaN   335       10
# 9   2013       TESLA         MODEL S (85 kWh battery)  ...    NaN   426       12
# 10  2013       TESLA              MODEL S PERFORMANCE  ...    NaN   426       12
# 11  2014   CHEVROLET                         SPARK EV  ...    NaN   131        7
# 12  2014        FORD                   FOCUS ELECTRIC  ...    NaN   122        4
# 13  2014  MITSUBISHI                           i-MiEV  ...    NaN   100        7
# 14  2014      NISSAN                             LEAF  ...    NaN   135        5
# 15  2014       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  ...    NaN   109        8
# 16  2014       SMART      FORTWO ELECTRIC DRIVE COUPE  ...    NaN   109        8
# 17  2014       TESLA         MODEL S (60 kWh battery)  ...    NaN   335       10
# 18  2014       TESLA         MODEL S (85 kWh battery)  ...    NaN   426       12
# 19  2014       TESLA              MODEL S PERFORMANCE  ...    NaN   426       12
# 20  2015         BMW                               i3  ...    NaN   130        4
# 21  2015   CHEVROLET                         SPARK EV  ...    NaN   131        7
# 22  2015        FORD                   FOCUS ELECTRIC  ...    NaN   122        4
# 23  2015         KIA                          SOUL EV  ...    NaN   149        4
# 24  2015  MITSUBISHI                           i-MiEV  ...    NaN   100        7
# 25  2015      NISSAN                             LEAF  ...    NaN   135        5
# 26  2015       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  ...    NaN   109        8
# 27  2015       SMART      FORTWO ELECTRIC DRIVE COUPE  ...    NaN   109        8
# 28  2015       TESLA         MODEL S (60 kWh battery)  ...    NaN   335       10
# 29  2015       TESLA         MODEL S (70 kWh battery)  ...    NaN   377       12
# 30  2015       TESLA      MODEL S (85/90 kWh battery)  ...    NaN   426       12
# 31  2015       TESLA                      MODEL S 70D  ...    NaN   386       12
# 32  2015       TESLA                  MODEL S 85D/90D  ...    NaN   435       12
# 33  2015       TESLA                MODEL S P85D/P90D  ...    NaN   407       12
# 34  2016         BMW                               i3  ...   10.0   130        4
# 35  2016   CHEVROLET                         SPARK EV  ...   10.0   131        7
# 36  2016        FORD                   FOCUS ELECTRIC  ...   10.0   122        4
# 37  2016         KIA                          SOUL EV  ...   10.0   149        4
# 38  2016  MITSUBISHI                           i-MiEV  ...   10.0   100        7
# 39  2016      NISSAN            LEAF (24 kWh battery)  ...   10.0   135        5
# 40  2016      NISSAN            LEAF (30 kWh battery)  ...   10.0   172        6
# 41  2016       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  ...   10.0   109        8
# 42  2016       SMART      FORTWO ELECTRIC DRIVE COUPE  ...   10.0   109        8
# 43  2016       TESLA         MODEL S (60 kWh battery)  ...   10.0   335       10
# 44  2016       TESLA         MODEL S (70 kWh battery)  ...   10.0   377       12
# 45  2016       TESLA      MODEL S (85/90 kWh battery)  ...   10.0   426       12
# 46  2016       TESLA                      MODEL S 70D  ...   10.0   386       12
# 47  2016       TESLA                  MODEL S 85D/90D  ...   10.0   435       12
# 48  2016       TESLA            MODEL S 90D (Refresh)  ...   10.0   473       12
# 49  2016       TESLA                MODEL S P85D/P90D  ...   10.0   407       12
# 50  2016       TESLA           MODEL S P90D (Refresh)  ...   10.0   435       12
# 51  2016       TESLA                      MODEL X 90D  ...   10.0   414       12
# 52  2016       TESLA                     MODEL X P90D  ...   10.0   402       12
#
# [53 rows x 17 columns]
